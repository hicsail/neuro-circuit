# %%
import platform; print(platform.platform())
import sys; print("Python", sys.version)
import starfish; print("starfish", starfish.__version__)
import napari; print("napari", napari.__version__)
# Out:
# Windows-10-10.0.14393-SP0
# Python 3.6.9 |Anaconda, Inc.| (default, Jul 30 2019, 14:00:49) [MSC v.1915 64 bit (AMD64)]
# starfish 0.1.5+23.g766d325
# napari 0.1.3
# WARNING: QSocketNotifier: Multiple socket notifiers for same socket 1000 and type Read

# %%
# make sure we can load the experiment
import starfish

experiment = starfish.Experiment.from_json("Z:/Projects/ARG/Animals/pr005/round2/sample2Round2_formatted/experiment.json")
for key in experiment.keys():
    print(key)
# Out:
# fov_000

# %%
#primary_image = experiment['fov_000'].get_image("primary")

# we can't load the whole stack for some reason... for now we'll just load a fraction of the image
primary_image = experiment['fov_000'].get_image("primary", zplanes=range(0,178), chs=range(0,1), x=slice(0, 500), y=slice(0, 500))

# %%
ipython = get_ipython()
ipython.magic("gui qt5")
viewer = starfish.display(primary_image)
viewer
# Out:
# WARNING: Traceback (most recent call last):
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\ipykernel\kernelapp.py", line 563, in start
#     self.io_loop.start()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\tornado\platform\asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\asyncio\base_events.py", line 438, in run_forever
#     self._run_once()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\asyncio\base_events.py", line 1451, in _run_once
#     handle._run()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\tornado\ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\tornado\gen.py", line 787, in inner
#     self.run()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\tornado\gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\ipykernel\kernelbase.py", line 272, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\ipykernel\kernelbase.py", line 542, in execute_request
#     user_expressions, allow_stdin,
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\ipykernel\ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\IPython\core\interactiveshell.py", line 2855, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in _run_cell
#     return runner(coro)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\IPython\core\interactiveshell.py", line 3058, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\IPython\core\interactiveshell.py", line 3249, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\IPython\core\interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-4-b9d2b4308cb7>", line 3, in <module>
#     viewer = starfish.display(primary_image)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\starfish\core\_display.py", line 228, in display
#     viewer = Viewer()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\napari\viewer.py", line 18, in __init__
#     self.window = Window(qt_viewer)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\napari\_qt\qt_main_window.py", line 74, in __init__
#     self.show()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\napari\_qt\qt_main_window.py", line 146, in show
#     self._qt_window.show()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\app\backends\_qt.py", line 501, in event
#     out = super(QtBaseCanvasBackend, self).event(ev)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\app\backends\_qt.py", line 501, in event
#     out = super(QtBaseCanvasBackend, self).event(ev)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\app\backends\_qt.py", line 818, in paintGL
#     self._vispy_canvas.events.draw(region=None)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\util\event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\util\event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   << caught exception here: >>
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\util\event.py", line 471, in _invoke_callback
#     cb(event)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\gloo\context.py", line 175, in flush_commands
#     self.shared.parser.parse([('CURRENT', 0, fbo)])
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\gloo\glir.py", line 819, in parse
#     self._parse(command)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\gloo\glir.py", line 743, in _parse
#     self._gl_initialize()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\gloo\glir.py", line 851, in _gl_initialize
#     if this_version < '2.1':
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\distutils\version.py", line 52, in __lt__
#     c = self._cmp(other)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\distutils\version.py", line 335, in _cmp
#     if self.version == other.version:
# AttributeError: 'LooseVersion' object has no attribute 'version'
# ERROR: Invoking <bound method GLContext.flush_commands of <GLContext at 0x2e821034e10>> for DrawEvent
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 178/178 [01:22<00:00,  2.15it/s]
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Traceback (most recent call last):
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\ipykernel\kernelapp.py", line 563, in start
#     self.io_loop.start()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\tornado\platform\asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\asyncio\base_events.py", line 438, in run_forever
#     self._run_once()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\asyncio\base_events.py", line 1451, in _run_once
#     handle._run()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\tornado\ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\tornado\gen.py", line 787, in inner
#     self.run()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\tornado\gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\ipykernel\kernelbase.py", line 272, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\ipykernel\kernelbase.py", line 542, in execute_request
#     user_expressions, allow_stdin,
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\ipykernel\ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\IPython\core\interactiveshell.py", line 2855, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in _run_cell
#     return runner(coro)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\IPython\core\interactiveshell.py", line 3058, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\IPython\core\interactiveshell.py", line 3249, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\IPython\core\interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-4-b9d2b4308cb7>", line 3, in <module>
#     viewer = starfish.display(primary_image)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\starfish\core\_display.py", line 241, in display
#     name="stack")
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\napari\components\viewer_model.py", line 370, in add_image
#     self.add_layer(layer)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\napari\components\viewer_model.py", line 313, in add_layer
#     self.layers.append(layer)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\napari\util\list\_model.py", line 56, in append
#     self.events.added(item=object, index=len(self) - 1)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\napari\util\event.py", line 508, in __call__
#     self._invoke_callback(cb, event)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\napari\util\event.py", line 523, in _invoke_callback
#     cb(event)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\napari\components\viewer_model.py", line 724, in _on_layers_change
#     self.dims.ndim = len(layer_range)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\napari\components\dims.py", line 137, in ndim
#     self.events.ndim()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\napari\util\event.py", line 508, in __call__
#     self._invoke_callback(cb, event)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\napari\util\event.py", line 523, in _invoke_callback
#     cb(event)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\napari\_qt\qt_dims.py", line 63, in update_ndim_listener
#     self.update_ndim.emit()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\napari\_qt\qt_dims.py", line 186, in _update_nsliders
#     self._update_display(i)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\napari\_qt\qt_dims.py", line 174, in _update_display
#     slider.show()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\app\backends\_qt.py", line 501, in event
#     out = super(QtBaseCanvasBackend, self).event(ev)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\app\backends\_qt.py", line 501, in event
#     out = super(QtBaseCanvasBackend, self).event(ev)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\app\backends\_qt.py", line 818, in paintGL
#     self._vispy_canvas.events.draw(region=None)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\util\event.py", line 455, in __call__
#     self._invoke_callback(cb, event)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\util\event.py", line 475, in _invoke_callback
#     self, cb_event=(cb, event))
#   << caught exception here: >>
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\gloo\gl\_gl2.py", line 53, in glBindFramebuffer
#     nativefunc = glBindFramebuffer._native
# AttributeError: 'function' object has no attribute '_native'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\gloo\gl\gl2.py", line 72, in _get_gl_func
#     func = getattr(_lib, name)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\ctypes\__init__.py", line 361, in __getattr__
#     func = self.__getitem__(name)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\ctypes\__init__.py", line 366, in __getitem__
#     func = self._FuncPtr((name_or_ordinal, self))
# AttributeError: function 'glBindFramebuffer' not found
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\util\event.py", line 471, in _invoke_callback
#     cb(event)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\scene\canvas.py", line 217, in on_draw
#     self._draw_scene()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\scene\canvas.py", line 266, in _draw_scene
#     self.draw_visual(self.scene)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\scene\canvas.py", line 304, in draw_visual
#     node.draw()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\scene\visuals.py", line 99, in draw
#     self._visual_superclass.draw(self)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\visuals\visual.py", line 443, in draw
#     self._vshare.index_buffer)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\visuals\shaders\program.py", line 101, in draw
#     Program.draw(self, *args, **kwargs)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\gloo\program.py", line 533, in draw
#     canvas.context.flush_commands()
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\gloo\context.py", line 175, in flush_commands
#     self.shared.parser.parse([('CURRENT', 0, fbo)])
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\gloo\glir.py", line 819, in parse
#     self._parse(command)
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\gloo\glir.py", line 745, in _parse
#     gl.glBindFramebuffer(gl.GL_FRAMEBUFFER, args[0])
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\gloo\gl\_gl2.py", line 55, in glBindFramebuffer
#     nativefunc = glBindFramebuffer._native = _get_gl_func("glBindFramebuffer", None, (ctypes.c_uint, ctypes.c_uint,))
#   File "c:\users\sail\.conda\envs\starfish-3.6\lib\site-packages\vispy\gloo\gl\gl2.py", line 87, in _get_gl_func
#     raise RuntimeError('Using %s with no OpenGL context.' % name)
# RuntimeError: Using glBindFramebuffer with no OpenGL context.
# ERROR: Invoking <bound method SceneCanvas.on_draw of <SceneCanvas (PyQt5) at 0x2e816152dd8>> for DrawEvent
# ERROR: Invoking <bound method GLContext.flush_commands of <GLContext at 0x2e821034e10>> repeat 2
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 490x291+874+477 on QWidgetWindow/'QMainWindowClassWindow'. Resulting geometry:  502x331+874+477 (frame: 8, 31, 8, 8, custom margin: 0, 0, 0, 0, minimum size: 490x291, maximum size: 16777215x16777215).
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# ERROR: Invoking <bound method SceneCanvas.on_draw of <SceneCanvas (PyQt5) at 0x2e816152dd8>> repeat 2
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# ERROR: Invoking <bound method GLContext.flush_commands of <GLContext at 0x2e821034e10>> repeat 4
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# ERROR: Invoking <bound method SceneCanvas.on_draw of <SceneCanvas (PyQt5) at 0x2e816152dd8>> repeat 4
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# ERROR: Invoking <bound method GLContext.flush_commands of <GLContext at 0x2e821034e10>> repeat 8
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# ERROR: Invoking <bound method SceneCanvas.on_draw of <SceneCanvas (PyQt5) at 0x2e816152dd8>> repeat 8
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# ERROR: Invoking <bound method GLContext.flush_commands of <GLContext at 0x2e821034e10>> repeat 16
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# ERROR: Invoking <bound method SceneCanvas.on_draw of <SceneCanvas (PyQt5) at 0x2e816152dd8>> repeat 16
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# ERROR: Invoking <bound method GLContext.flush_commands of <GLContext at 0x2e821034e10>> repeat 32
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# ERROR: Invoking <bound method SceneCanvas.on_draw of <SceneCanvas (PyQt5) at 0x2e816152dd8>> repeat 32
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# ERROR: Invoking <bound method GLContext.flush_commands of <GLContext at 0x2e821034e10>> repeat 64
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# ERROR: Invoking <bound method SceneCanvas.on_draw of <SceneCanvas (PyQt5) at 0x2e816152dd8>> repeat 64
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
# WARNING: Error drawing visual <Image at 0x2e824d809e8>
